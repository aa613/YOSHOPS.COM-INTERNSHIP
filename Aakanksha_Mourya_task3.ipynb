# %%
# !pip install -U autoscraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autoscraper
#   Downloading autoscraper-1.1.14-py3-none-any.whl (10 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from autoscraper) (0.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autoscraper) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from autoscraper) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->autoscraper) (4.6.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autoscraper) (3.0.4)
# Installing collected packages: autoscraper
# Successfully installed autoscraper-1.1.14

# %%
# importing the dependencies
import pandas as pd
from autoscraper import AutoScraper

# %%
# providing the data to autoscraper object
url = "https://yoshops.com/products"
data = ['https://yoshops.com/products/reliance-jio-phone1', 'Reliance Jio Phone','https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1354_original/:/rs=w:600,h:600']
scrap = AutoScraper()
result = scrap.build(url, data)
print(result)
# Out:
# ['https://yoshops.com/products/reliance-jio-phone1', 'https://yoshops.com/products/summer-internship-gift', 'https://yoshops.com/products/boat-rockerz-255-wireless-bluetooth-headset-with-mic-black', 'https://yoshops.com/products/sony-playstation-ps2-gaming-console-150-gb-hard-disk-with-50-games-preloaded-black', 'https://yoshops.com/products/boat-airdopes-x3-bass-wireless-earbuds-with-charging-case-white', 'https://yoshops.com/products/hx-750-remote-control-flying-drone', 'https://yoshops.com/products/boat-rockerz-530-foldable-bluetooth-headphone-with-mic-carbon-black', 'https://yoshops.com/products/reliance-jio-phone-2', 'https://yoshops.com/products/yoshops-vr-box-virtual-reality-glasses-headset-2-0-view-suitable-for-4-6-inch-smartphones', 'https://yoshops.com/products/samsung-level-u-bluetooth-wireless-in-ear-headphones-with-mic-black', 'https://yoshops.com/products/barbie-doll', 'https://yoshops.com/products/zebronics-external-tv-tuner-card-tl1010', 'https://yoshops.com/products/sony-playstation-3-console-slim-320-gb-black', 'https://yoshops.com/products/hx-713-remote-control-helicopter', 'https://yoshops.com/products/boat-nirvanaa-uno-wired-in-ear-earphones-with-mic-black', 'https://yoshops.com/products/jbl-tempo-on-ear-headphone', 'https://yoshops.com/products/boat-rockerz-225-wireless-bluetooth-headset-with-mic-black', 'https://yoshops.com/products/refer-and-earn-rs-2000-and-get-free-partnership-gift', 'https://yoshops.com/products/xn-jbl-tempo-on-ear-headphone-with-mic-ms176-black-et05a', 'https://yoshops.com/products/xn-sony-on-ear-headphone-with-mic-ms177-black-jt71a', 'https://yoshops.com/products/mi-neckband-bluetooth-headset-with-mic-black', 'https://yoshops.com/products/data-science-internship-training-program-with-free-gift-jiobook-laptop', 'https://yoshops.com/products/1-kg-chicken-biryani', 'https://yoshops.com/products/yoshops-referral-gift', 'https://yoshops.com/products/zebronics-zeb-u740-ups-600va', 'https://yoshops.com/products/puppy-house-coin-piggy-bank', 'https://yoshops.com/products/the-amazing-spider-man-q-series-24ghz-rc-quad-copter-drone', 'https://yoshops.com/products/super-power-jcb-truck-construction-loader-excavator-crane-toys1', 'https://yoshops.com/products/falcon-drone-four-axis-aircraft-with-2-4-ghz-rc-blade-guard-headless-mode-led-without-camera', 'https://yoshops.com/products/dell-kb216-multimedia-usb-wired-keyboard', 'https://yoshops.com/products/kids-drone-quadcopter-2-4g-6-channel-without-camera', 'https://yoshops.com/products/boat-rockerz-335-stereo-earphones-blackgold', 'https://yoshops.com/products/sony-playstation-ps2-with-in-built-dvd-player-black', 'https://yoshops.com/products/blockchain-developer-internship-training-program1', 'https://yoshops.com/products/hospitality-internship-training-program1', 'https://yoshops.com/products/cyber-security-internship-training-program', 'https://yoshops.com/products/lava-captain-n1-red', 'https://yoshops.com/products/vmax-vision-hx763-drone-remote-control-quadrocopter', 'https://yoshops.com/products/hx770-v-max-aircraft-drone', 'https://yoshops.com/products/captain-america-24ghz-rc-quad-copter-drone', 'https://yoshops.com/products/samsung-u-flex-wireless-bluetooth-flexible-headphones-with-mic-black', 'https://yoshops.com/products/avengers-captain-america-drone-four-axis-aircraft-with-2-4-ghz-rc-blade-guard-headless-mode-led-without-camera', 'https://yoshops.com/products/sound-true-sq2', 'https://yoshops.com/products/1-bucket-chechen-biryani-party-pack-5kg', 'https://yoshops.com/products/mitsonic-mt2001-53cm-20-full-hd-led-television', 'https://yoshops.com/products/spider-man-mini-drone', 'https://yoshops.com/products/machine-learning-training-internship-program-with-free-gift-jiobook-laptop', 'https://yoshops.com/products/bigdata-hadoop-training-internship-program-with-free-gift-jiobook-laptop', 'Reliance Jio Phone', 'Summer Internship Gift', 'Boat Rockerz 255 Wireless Bluetooth Headset with Mic (Black)', 'Sony PlayStation PS2 Gaming Console  ...

# %%
# fetching the data
scrap.get_result_similar(url, grouped=True)
# Out:
# {'rule_lsrg': ['https://yoshops.com/products/reliance-jio-phone1',
#   'https://yoshops.com/products/summer-internship-gift',
#   'https://yoshops.com/products/boat-rockerz-255-wireless-bluetooth-headset-with-mic-black',
#   'https://yoshops.com/products/sony-playstation-ps2-gaming-console-150-gb-hard-disk-with-50-games-preloaded-black',
#   'https://yoshops.com/products/boat-airdopes-x3-bass-wireless-earbuds-with-charging-case-white',
#   'https://yoshops.com/products/hx-750-remote-control-flying-drone',
#   'https://yoshops.com/products/boat-rockerz-530-foldable-bluetooth-headphone-with-mic-carbon-black',
#   'https://yoshops.com/products/reliance-jio-phone-2',
#   'https://yoshops.com/products/yoshops-vr-box-virtual-reality-glasses-headset-2-0-view-suitable-for-4-6-inch-smartphones',
#   'https://yoshops.com/products/samsung-level-u-bluetooth-wireless-in-ear-headphones-with-mic-black',
#   'https://yoshops.com/products/barbie-doll',
#   'https://yoshops.com/products/zebronics-external-tv-tuner-card-tl1010',
#   'https://yoshops.com/products/sony-playstation-3-console-slim-320-gb-black',
#   'https://yoshops.com/products/hx-713-remote-control-helicopter',
#   'https://yoshops.com/products/boat-nirvanaa-uno-wired-in-ear-earphones-with-mic-black',
#   'https://yoshops.com/products/jbl-tempo-on-ear-headphone',
#   'https://yoshops.com/products/boat-rockerz-225-wireless-bluetooth-headset-with-mic-black',
#   'https://yoshops.com/products/refer-and-earn-rs-2000-and-get-free-partnership-gift',
#   'https://yoshops.com/products/xn-jbl-tempo-on-ear-headphone-with-mic-ms176-black-et05a',
#   'https://yoshops.com/products/xn-sony-on-ear-headphone-with-mic-ms177-black-jt71a',
#   'https://yoshops.com/products/mi-neckband-bluetooth-headset-with-mic-black',
#   'https://yoshops.com/products/data-science-internship-training-program-with-free-gift-jiobook-laptop',
#   'https://yoshops.com/products/1-kg-chicken-biryani',
#   'https://yoshops.com/products/yoshops-referral-gift',
#   'https://yoshops.com/products/zebronics-zeb-u740-ups-600va',
#   'https://yoshops.com/products/puppy-house-coin-piggy-bank',
#   'https://yoshops.com/products/the-amazing-spider-man-q-series-24ghz-rc-quad-copter-drone',
#   'https://yoshops.com/products/super-power-jcb-truck-construction-loader-excavator-crane-toys1',
#   'https://yoshops.com/products/falcon-drone-four-axis-aircraft-with-2-4-ghz-rc-blade-guard-headless-mode-led-without-camera',
#   'https://yoshops.com/products/dell-kb216-multimedia-usb-wired-keyboard',
#   'https://yoshops.com/products/kids-drone-quadcopter-2-4g-6-channel-without-camera',
#   'https://yoshops.com/products/boat-rockerz-335-stereo-earphones-blackgold',
#   'https://yoshops.com/products/sony-playstation-ps2-with-in-built-dvd-player-black',
#   'https://yoshops.com/products/blockchain-developer-internship-training-program1',
#   'https://yoshops.com/products/hospitality-internship-training-program1',
#   'https://yoshops.com/products/cyber-security-internship-training-program',
#   'https://yoshops.com/products/lava-captain-n1-red',
#   'https://yoshops.com/products/vmax-vision-hx763-drone-remote-control-quadrocopter',
#   'https://yoshops.com/products/hx770-v-max-aircraft-drone',
#   'https://yoshops.com/products/captain-america-24ghz-rc-quad-copter-drone',
#   'https://yoshops.com/products/samsung-u-flex-wireless-bluetooth-flexible-headphones-with-mic-black',
#   'https://yoshops.com/products/avengers-captain-america-drone-four-axis-aircraft-with-2-4-ghz-rc-blade-guard-headless-mode-led-without-camera',
#   'https://yoshops.com/products/sound-true-sq2',
#   'https://yoshops.com/products/1-bucket-chechen-biryani-party-pack-5kg',
#   'https://yoshops.com/products/mitsonic-mt2001-53cm-20-full-hd-led-television',
#   'https://yoshops.com/products/spider-man-mini-drone',
#   'https://yoshops.com/products/machine-learning-training-internship-program-with-free-gift-jiobook-laptop',
#   'https://yoshops.com/products/bigdata-hadoop-training-internship-program-with-free-gift-jiobook-laptop'],
#  'rule_m1l7': ['https://yoshops.com/products/reliance-jio-phone1',
#   'https://yoshops.com/products/summer-internship-gift',
#   'https://yoshops.com/products/boat-rockerz-255-wireless-bluetooth-headset-with-mic-black',
#   'https://yoshops.com/products/sony-playstation-ps2-gaming-console-150-gb-hard-disk-with-50-games-preloaded-black',
#   'https://yoshops.com/products/boat-airdopes-x3-bass-wireless-earbuds-with-charging-case-white',
#   'https://yoshops.com/products/hx-750-remote-control-flying-drone',
#   'https://yoshops.com/products/boat-rockerz-530-foldable-bluetooth-headphone-with-mic-carbon-black',
#   'https://yoshops.com/products/reliance-jio-phone-2',
#   'https://yoshops.com/products/yoshops-vr-box-virtual-reality-glasses-headset-2-0-view-suitable-for-4-6-inch-smartphones',
#   'https://yoshops.com/products/samsung-level-u-bluetooth-wireless-in-ear-headphones-with-mic-black',
#   'https://yoshops.com/products/barbie-doll',
#   'https://yoshops.com/products/zebronics-external-tv-tuner-card-tl1010',
#   'https://yoshops.com/products/sony-playstation-3-console-slim-320-gb-black',
#   'https://yoshops.com/products/hx-713-remote-control-helicopter',
#   'https://yoshops.com/products/boat-nirvanaa-uno-wired-in-ear-earphones-with-mic-black',
#   'https://yoshops.com/products/jbl-tempo-on-ear-headphone',
#   'https://yoshops.com/products/boat-rockerz-225-wireless-bluetooth-headset-with-mic-black',
#   'https://yoshops.com/products/refer-and-earn-rs-2000-and-get-free-partnership-gift',
#   'https://yoshops.com/products/xn-jbl-tempo-on-ear-headphone-with-mic-ms176-black-et05a',
#   'https://yoshops.com/products/xn-sony-on-ear-headphone-with-mic-ms177-black-jt71a',
#   'https://yoshops.com/products/mi-neckband-bluetooth-headset-with-mic-black',
#   'https://yoshops.com/products/data-science-internship-training-program-with-free-gift-jiobook-laptop',
#   'https://yoshops.com/products/1-kg-chicken-biryani',
#   'https://yoshops.com/products/yoshops-referral-gift',
#   'https://yoshops.com/products/zebronics-zeb-u740-ups-600va',
#   'https://yoshops.com/products/puppy-house-coin-piggy-bank',
#   'https://yoshops.com/products/the-amazing-spider-man-q-series-24ghz-rc-quad-copter-drone',
#   'https://yoshops.com/products/super-power-jcb-truck-construction-loader-excavator-crane-toys1',
#   'https://yoshops.com/products/falcon-drone-four-axis-aircraft-with-2-4-ghz-rc-blade-guard-headless-mode-led-without-camera',
#   'https://yoshops.com/products/dell-kb216-multimedia-usb-wired-keyboard',
#   'https://yoshops.com/products/kids-drone-quadcopter-2-4g-6-channel-without-camera',
#   'https://yoshops.com/products/boat-rockerz-335-stereo-earphones-blackgold',
#   'https://yoshops.com/products/sony-playstation-ps2-with-in-built-dvd-player-black',
#   'https://yoshops.com/products/blockchain-developer-internship-training-program1',
#   'https://yoshops.com/products/hospitality-internship-training-program1',
#   'https://yoshops.com/products/cyber-security-internship-training-program',
#   'https://yoshops.com/products/lava-captain-n1-red',
#   'https://yoshops.com/products/vmax-vision-hx763-drone-remote-control-quadrocopter',
#   'https://yoshops.com/products/hx770-v-max-aircraft-drone',
#   'https://yoshops.com/products/captain-america-24ghz-rc-quad-copter-drone',
#   'https://yoshops.com/products/samsung-u-flex-wireless-bluetooth-flexible-headphones-with-mic-black',
#   'https://yoshops.com/products/avengers-captain-america-drone-four-axis-aircraft-with-2-4-ghz-rc-blade-guard-headless-mode-led-without-camera',
#   'https://yoshops.com/products/sound-true-sq2',
#   'https://yoshops.com/products/1-bucket-chechen-biryani-party-pack-5kg',
#   'https://yoshops.com/products/mitsonic-mt2001-53cm-20-full-hd-led-television',
#   'https://yoshops.com/products/spider-man-mini-drone',
#   'https://yoshops.com/products/machine-learning-training-internship-program-with-free-gift-jiobook-laptop',
#   'https://yoshops.com/products/bigdata-hadoop-training-internship-program-with-free-gift-jiobook-laptop'],
#  'rule_dhjy': ['Reliance Jio Phone',
#   'Summer Internship Gift',
#   'Boat Rockerz 255 Wireless Bluetooth Headset with Mic (Black)',
#   'Sony PlayStation PS2 Gaming Console 150 GB Hard Disk With 50 Games Preloaded(Black)',
#   'boAT Airdopes X3 Bass Wireless Earbuds with Charging Case (White)',
#   'Vmax HX 750 Quadcopter Drone (No Camera)',
#   'Boat Rockerz 530 Foldable Bluetooth Headphone with Mic (Carbon Black)',
#   'Reliance Jio Phone 2',
#   'Yoshops VR BOX Virtual Reality Glasses Headset 2.0 View Suitable For 4-6 Inch Smartphones',
#   'Samsung Level U Bluetooth Wireless in-Ear Headphones With Mic (Black)',
#   'Barbie Doll (blue)',
#   'Zebronics External TV Tuner Card TL1010',
#   'Sony PlayStation PS3 Console Slim 320 GB (Black)',
#   'HX-713 Remote Control Helicopter',
#   'Boat Nirvanaa Uno Wired In-ear Earphones with Mic (Black)',
#   'JBL Tempo On-Ear Headphone',
#   'Boat Rockerz 225 Plastic Wireless Bluetooth Headset with Mic (Black)',
#   'Refer and Earn Rs.2000 and Get Free Partnership Gift',
#   'JBL Tempo On-Ear Headphone With Mic – MS176 (Black)',
#   'Sony On-Ear Phone With Microphone Wired Headphones MS177',
#   'Mi Neckband Bluetooth Headset with Mic (Black)',
#   'Data Science Training Internship Program with Free Gift JioBook Laptop',
#   '1KG Chicken Biryani (Chennai)',
#   'Yoshops Referral Gift',
#   'Zebronics ZEB-U740 UPS 600VA',
#   'Puppy House Coin Piggy Bank',
#   'The Amazing Spider Man Micro Drone Q Series Hyun Lights Upgraded Quadcopter Headless Mode One Key Features',
#   'Super Power JCB Truck Construction Loader Excavator Crane Toys',
#   'Falcon Drone Four Axis Aircraft with 2.4 GHz RC, Blade Guard, Headless Mode LED Without Camera',
#   'Dell KB216 Multimedia USB Wired Keyboard',
#   'Kids Drone Quadcopter 2.4G 6-Channel Without Camera',
#   'Boat Rockerz 335 STEREO EARPHONES (Black/Gold)',
#   'Sony PlayStation PS1 with in-built DVD Player (Black)',
#   'Blockchain Developer Internship Training Program',
#   'Hospitality Internship Training Program',
#   'Cyber Security Internship Training Program',
#   'Lava Captain N1 Red',
#   'VMax HX763 Vision Drone 2.4GHz RC Quad-copter Headless Mode One Key Without Camera',
#   'HX770 V-Max Aircraft Drone',
#   'Diabolo Captain America Civil War Q Series Hyun Lights Upgraded Mini Drone Without Camera',
#   'Samsung U Flex Wireless Bluetooth Flexible Headphones with Mic (Black)',
#   'Avengers Captain America Drone Four Axis Aircraft with 2.4 GHz Without Camera',
#   'BOSE Sound True SQ2 Headphones Pouch (Black)',
#   '1 Bucket Chicken Biryani Party Pack 5kg (Chennai)',
#   'MitSonic 20 Inches (53 cm) FULL HD Gorilla Glass LED TV',
#   'Spider Man Mini Drone',
#   'Machine learning Training Internship Program with Free Gift JioBook Laptop',
#   'BigData Hadoop Training Internship Program with Free Gift JioBook Laptop'],
#  'rule_m0po': ['Reliance Jio Phone',
#   'Summer Internship Gift',
#   'Boat Rockerz 255 Wireless Bluetooth Headset with Mic (Black)',
#   'Sony PlayStation PS2 Gaming Console 150 GB Hard Disk With 50 Games Preloaded(Black)',
#   'boAT Airdopes X3 Bass Wireless Earbuds with Charging Case (White)',
#   'Vmax HX 750 Quadcopter Drone (No Camera)',
#   'Boat Rockerz 530 Foldable Bluetooth Headphone with Mic (Carbon Black)',
#   'Reliance Jio Phone 2',
#   'Yoshops VR BOX Virtual Reality Glasses Headset 2.0 View Suitable For 4-6 Inch Smartphones',
#   'Samsung Level U Bluetooth Wireless in-Ear Headphones With Mic (Black)',
#   'Barbie Doll (blue)',
#   'Zebronics External TV Tuner Card TL1010',
#   'Sony PlayStation PS3 Console Slim 320 GB (Black)',
#   'HX-713 Remote Control Helicopter',
#   'Boat Nirvanaa Uno Wired In-ear Earphones with Mic (Black)',
#   'JBL Tempo On-Ear Headphone',
#   'Boat Rockerz 225 Plastic Wireless Bluetooth Headset with Mic (Black)',
#   'Refer and Earn Rs.2000 and Get Free Partnership Gift',
#   'JBL Tempo On-Ear Headphone With Mic – MS176 (Black)',
#   'Sony On-Ear Phone With Microphone Wired Headphones MS177',
#   'Mi Neckband Bluetooth Headset with Mic (Black)',
#   'Data Science Training Internship Program with Free Gift JioBook Laptop',
#   '1KG Chicken Biryani (Chennai)',
#   'Yoshops Referral Gift',
#   'Zebronics ZEB-U740 UPS 600VA',
#   'Puppy House Coin Piggy Bank',
#   'The Amazing Spider Man Micro Drone Q Series Hyun Lights Upgraded Quadcopter Headless Mode One Key Features',
#   'Super Power JCB Truck Construction Loader Excavator Crane Toys',
#   'Falcon Drone Four Axis Aircraft with 2.4 GHz RC, Blade Guard, Headless Mode LED Without Camera',
#   'Dell KB216 Multimedia USB Wired Keyboard',
#   'Kids Drone Quadcopter 2.4G 6-Channel Without Camera',
#   'Boat Rockerz 335 STEREO EARPHONES (Black/Gold)',
#   'Sony PlayStation PS1 with in-built DVD Player (Black)',
#   'Blockchain Developer Internship Training Program',
#   'Hospitality Internship Training Program',
#   'Cyber Security Internship Training Program',
#   'Lava Captain N1 Red',
#   'VMax HX763 Vision Drone 2.4GHz RC Quad-copter Headless Mode One Key Without Camera',
#   'HX770 V-Max Aircraft Drone',
#   'Diabolo Captain America Civil War Q Series Hyun Lights Upgraded Mini Drone Without Camera',
#   'Samsung U Flex Wireless Bluetooth Flexible Headphones with Mic (Black)',
#   'Avengers Captain America Drone Four Axis Aircraft with 2.4 GHz Without Camera',
#   'BOSE Sound True SQ2 Headphones Pouch (Black)',
#   '1 Bucket Chicken Biryani Party Pack 5kg (Chennai)',
#   'MitSonic 20 Inches (53 cm) FULL HD Gorilla Glass LED TV',
#   'Spider Man Mini Drone',
#   'Machine learning Training Internship Program with Free Gift JioBook Laptop',
#   'BigData Hadoop Training Internship Program with Free Gift JioBook Laptop'],
#  'rule_osar': ['Reliance Jio Phone',
#   'Summer Internship Gift',
#   'Boat Rockerz 255 Wireless Bluetooth Headset with Mic (Black)',
#   'Sony PlayStation PS2 Gaming Console 150 GB Hard Disk With 50 Games Preloaded(Black)',
#   'boAT Airdopes X3 Bass Wireless Earbuds with Charging Case (White)',
#   'Vmax HX 750 Quadcopter Drone (No Camera)',
#   'Boat Rockerz 530 Foldable Bluetooth Headphone with Mic (Carbon Black)',
#   'Reliance Jio Phone 2',
#   'Yoshops VR BOX Virtual Reality Glasses Headset 2.0 View Suitable For 4-6 Inch Smartphones',
#   'Samsung Level U Bluetooth Wireless in-Ear Headphones With Mic (Black)',
#   'Barbie Doll (blue)',
#   'Zebronics External TV Tuner Card TL1010',
#   'Sony PlayStation PS3 Console Slim 320 GB (Black)',
#   'HX-713 Remote Control Helicopter',
#   'Boat Nirvanaa Uno Wired In-ear Earphones with Mic (Black)',
#   'JBL Tempo On-Ear Headphone',
#   'Boat Rockerz 225 Plastic Wireless Bluetooth Headset with Mic (Black)',
#   'Refer and Earn Rs.2000 and Get Free Partnership Gift',
#   'JBL Tempo On-Ear Headphone With Mic – MS176 (Black)',
#   'Sony On-Ear Phone With Microphone Wired Headphones MS177',
#   'Mi Neckband Bluetooth Headset with Mic (Black)',
#   'Data Science Training Internship Program with Free Gift JioBook Laptop',
#   '1KG Chicken Biryani (Chennai)',
#   'Yoshops Referral Gift',
#   'Zebronics ZEB-U740 UPS 600VA',
#   'Puppy House Coin Piggy Bank',
#   'The Amazing Spider Man Micro Drone Q Series Hyun Lights Upgraded Quadcopter Headless Mode One Key Features',
#   'Super Power JCB Truck Construction Loader Excavator Crane Toys',
#   'Falcon Drone Four Axis Aircraft with 2.4 GHz RC, Blade Guard, Headless Mode LED Without Camera',
#   'Dell KB216 Multimedia USB Wired Keyboard',
#   'Kids Drone Quadcopter 2.4G 6-Channel Without Camera',
#   'Boat Rockerz 335 STEREO EARPHONES (Black/Gold)',
#   'Sony PlayStation PS1 with in-built DVD Player (Black)',
#   'Blockchain Developer Internship Training Program',
#   'Hospitality Internship Training Program',
#   'Cyber Security Internship Training Program',
#   'Lava Captain N1 Red',
#   'VMax HX763 Vision Drone 2.4GHz RC Quad-copter Headless Mode One Key Without Camera',
#   'HX770 V-Max Aircraft Drone',
#   'Diabolo Captain America Civil War Q Series Hyun Lights Upgraded Mini Drone Without Camera',
#   'Samsung U Flex Wireless Bluetooth Flexible Headphones with Mic (Black)',
#   'Avengers Captain America Drone Four Axis Aircraft with 2.4 GHz Without Camera',
#   'BOSE Sound True SQ2 Headphones Pouch (Black)',
#   '1 Bucket Chicken Biryani Party Pack 5kg (Chennai)',
#   'MitSonic 20 Inches (53 cm) FULL HD Gorilla Glass LED TV',
#   'Spider Man Mini Drone',
#   'Machine learning Training Internship Program with Free Gift JioBook Laptop',
#   'BigData Hadoop Training Internship Program with Free Gift JioBook Laptop'],
#  'rule_95i3': ['https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1354_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3600_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2169_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3083_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1923_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1660_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3070_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2303_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/366_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2056_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4031_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2656_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2369_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1333_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1988_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1205_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1956_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3610_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2925_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2947_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2026_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4112_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3956_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3996_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1598_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1404_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2165_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2240_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3012_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1424_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1460_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1927_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1800_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3620_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3628_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/3636_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1269_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2161_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1719_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2160_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2046_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/2981_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1305_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1445_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1199_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/1641_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4117_original/:/rs=w:600,h:600',
#   'https://isteam.wsimg.com/ip/a8efe83b-6857-477d-9d0f-f13ca0229a20/ols/4124_original/:/rs=w:600,h:600']}

# %%
scrap.set_rule_aliases({'rule_lsrg': 'product_link','rule_dhjy': 'Title' , 'rule_95i3' :"img_link"})
scrap.save('yoshops_products')

# %%
# getting data from different pages
page_1=scrap.get_result_similar('https://yoshops.com/products',group_by_alias=True)
page_2=scrap.get_result_similar('https://yoshops.com/products?page=2',group_by_alias=True)
page_3=scrap.get_result_similar('https://yoshops.com/products?page=3',group_by_alias=True)
page_4=scrap.get_result_similar('https://yoshops.com/products?page=4',group_by_alias=True)
page_5=scrap.get_result_similar('https://yoshops.com/products?page=5',group_by_alias=True)
page_6=scrap.get_result_similar('https://yoshops.com/products?page=6',group_by_alias=True)
page_7=scrap.get_result_similar('https://yoshops.com/products?page=7',group_by_alias=True)
page_8=scrap.get_result_similar('https://yoshops.com/products?page=8',group_by_alias=True)
page_9=scrap.get_result_similar('https://yoshops.com/products?page=9',group_by_alias=True)
page_10=scrap.get_result_similar('https://yoshops.com/products?page=10',group_by_alias=True)
page_11=scrap.get_result_similar('https://yoshops.com/products?page=11',group_by_alias=True)
page_12=scrap.get_result_similar('https://yoshops.com/products?page=12',group_by_alias=True)

# %%
# creating dataframe for pages
df1=pd.DataFrame({"product-link":page_1['product_link'],
                  "product_title": page_1['Title'],
                  "product_image_link": page_1['img_link']})


df2=pd.DataFrame({"product-link":page_2['product_link'],
                  "product_title": page_2['Title'],
                  "product_image_link": page_2['img_link']})

df3=pd.DataFrame({"product-link":page_3['product_link'],
                  "product_title": page_3['Title'],
                  "product_image_link": page_3['img_link']})

df4=pd.DataFrame({"product-link":page_4['product_link'],
                  "product_title": page_4['Title'],
                  "product_image_link": page_4['img_link']})


df5=pd.DataFrame({"product-link":page_5['product_link'],
                  "product_title": page_5['Title'],
                  "product_image_link": page_5['img_link']})

df6=pd.DataFrame({"product-link":page_6['product_link'],
                  "product_title": page_6['Title'],
                  "product_image_link": page_6['img_link']})


df7=pd.DataFrame({"product-link":page_7['product_link'],
                  "product_title": page_7['Title'],
                  "product_image_link": page_7['img_link']})


df8=pd.DataFrame({"product-link":page_8['product_link'],
                  "product_title": page_8['Title'],
                  "product_image_link": page_8['img_link']})


df9=pd.DataFrame({"product-link":page_9['product_link'],
                  "product_title": page_9['Title'],
                  "product_image_link": page_9['img_link']})

df10=pd.DataFrame({"product-link":page_10['product_link'],
                  "product_title": page_10['Title'],
                  "product_image_link": page_10['img_link']})


df11=pd.DataFrame({"product-link":page_11['product_link'],
                  "product_title": page_11['Title'],
                  "product_image_link": page_11['img_link']})


df12=pd.DataFrame({"product-link":page_12['product_link'],
                  "product_title": page_12['Title'],
                  "product_image_link": page_12['img_link']})

# %%
# create one final df of all the dfs
final_df = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12], axis=0)

# %%
# peeking at the df
final_df.head()
# Out:
#                                         product-link  \
# 0   https://yoshops.com/products/reliance-jio-phone1
# 1  https://yoshops.com/products/summer-internship...
# 2  https://yoshops.com/products/boat-rockerz-255-...
# 3  https://yoshops.com/products/sony-playstation-...
# 4  https://yoshops.com/products/boat-airdopes-x3-...
#
#                                        product_title  \
# 0                                 Reliance Jio Phone
# 1                             Summer Internship Gift
# 2  Boat Rockerz 255 Wireless Bluetooth Headset wi...
# 3  Sony PlayStation PS2 Gaming Console 150 GB Har...
# 4  boAT Airdopes X3 Bass Wireless Earbuds with Ch...
#
#                                   product_image_link
# 0  https://isteam.wsimg.com/ip/a8efe83b-6857-477d...
# 1  https://isteam.wsimg.com/ip/a8efe83b-6857-477d...
# 2  https://isteam.wsimg.com/ip/a8efe83b-6857-477d...
# 3  https://isteam.wsimg.com/ip/a8efe83b-6857-477d...
# 4  https://isteam.wsimg.com/ip/a8efe83b-6857-477d...

# %%
# fetching missing images links
missing_images=final_df[final_df['product_image_link'].str.contains('//onlinestore.wsimg.com/assets/noimage/product-5fec99477aebb10bac85d82665ec1497de4536cda3279e59089555c45cf589fa.png')]
missing_images.head()
# Out:
#                                          product-link  \
# 33  https://yoshops.com/products/river-prawn-small...
# 15  https://yoshops.com/products/rohu-river-fish-r...
# 16  https://yoshops.com/products/rohu-river-fish-c...
# 17  https://yoshops.com/products/vakura-catla-rive...
# 19  https://yoshops.com/products/river-prawn-raw-b...
#
#                                       product_title  \
# 33          River Prawn Small- 4cm 250gm(Berhampur)
# 15               Rohu River Fish Raw 1Kg(Berhampur)
# 16  Rohu River Fish Cutting(No Head) 1Kg(Berhampur)
# 17       Vakura Catla River Fish Raw 1Kg(Berhampur)
# 19        River Prawn Raw Big-12cm 250gm(Berhampur)
#
#                                    product_image_link
# 33  //onlinestore.wsimg.com/assets/noimage/product...
# 15  //onlinestore.wsimg.com/assets/noimage/product...
# 16  //onlinestore.wsimg.com/assets/noimage/product...
# 17  //onlinestore.wsimg.com/assets/noimage/product...
# 19  //onlinestore.wsimg.com/assets/noimage/product...

# %%
# checking the shape of missing_images df
missing_images.shape
# Out:
# (12, 3)

# %%
# putting the required data into Excel
missing_images['product_details'] = missing_images['product-link'].str.split("/" , expand=True)[4]
missing_images.to_excel('missing_images.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
